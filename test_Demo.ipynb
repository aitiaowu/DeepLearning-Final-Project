# %%
# !git clone https://github.com/aitiaowu/DeepLearning-Final-Project.git
# Out:
# Cloning into 'DeepLearning-Final-Project'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 127 (delta 42), reused 119 (delta 37), pack-reused 0
# Receiving objects: 100% (127/127), 78.77 MiB | 32.24 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %% [markdown]
# Demo, play with shared data and models :)

# %%
# ================= Configuration ================= #
# %cd /content/DeepLearning-Final-Project/Semantic_Segmentation/synth_data/
# !pip install -r requirements.txt
# Out:
# /content/DeepLearning-Final-Project/Semantic_Segmentation/synth_data
# ...
#      |████████████████████████████████| 676 kB 13.8 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.4 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=76dad4fde2972f86de4e3f4a32c37193c242b6cff1ec783a364c83a8e165210a
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=88fca2cb00bfb6430cce8c7598dc73ad7ba00c44ff2c9820b4fdbaa6e0a5c12b
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
# %cd /content/DeepLearning-Final-Project/Test/synth_data/
# !python test_phase1.py --dataroot /content/DeepLearning-Final-Project/datasets/depth2edge_real/ --name depth2edge_synth --model our --netG encoder_decoder_256 --netD LeNet --direction AtoB --dataset_mode onehotAligned --norm batch --checkpoints_dir /content/DeepLearning-Final-Project/ckpt/ --results_dir /content/result/ --input_nc 1 --output_nc 3 --epoch 199
# Out:
# /content/DeepLearning-Final-Project/Test/synth_data
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/DeepLearning-Final-Project/ckpt/	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/DeepLearning-Final-Project/datasets/depth2edge_real/	[default: None]
#           dataroot_target: None
#              dataset_mode: onehotAligned                 	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: 199                           	[default: latest]
#                      eval: False
#                   gpu_ids: -1
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
# ...

# %%
# %cd /content/DeepLearning-Final-Project/Test/synth_data/
# !python test_phase1.py --dataroot /content/DeepLearning-Final-Project/datasets/depth2edge_real/ --name DA --model our --netG encoder_decoder_256 --netD LeNet --direction AtoB --dataset_mode onehotAligned --norm batch --checkpoints_dir /content/DeepLearning-Final-Project/ckpt/ --results_dir /content/result/ --input_nc 1 --output_nc 3 --epoch 50
# Out:
# /content/DeepLearning-Final-Project/Test/synth_data
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/DeepLearning-Final-Project/ckpt/	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/DeepLearning-Final-Project/datasets/depth2edge_real/	[default: None]
#           dataroot_target: None
#              dataset_mode: onehotAligned                 	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: 50                            	[default: latest]
#                      eval: False
#                   gpu_ids: -1
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
# ...

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.figure(figsize=(20,10))
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/0_real_A.png')
plt.subplot(2,3,1)
plt.title('Depth map')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/0_fake_B_visual.png')
plt.subplot(2,3,2)
plt.title('Sythetic/real')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/0_real_B_visual.png')
plt.subplot(2,3,3)
plt.title('GT')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/10_real_A.png')
plt.subplot(2,3,4)
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/10_fake_B_visual.png')
plt.subplot(2,3,5)
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/depth2edge_synth/test_199/images/10_real_B_visual.png')
plt.subplot(2,3,6)
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(20,10))
img = mpimg.imread('/content/result/DA/test_50/images/0_real_A.png')
plt.subplot(2,3,1)
plt.title('Depth map')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/DA/test_50/images/0_fake_B_visual.png')
plt.subplot(2,3,2)
plt.title('Domain adaptation')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/DA/test_50/images/0_real_B_visual.png')
plt.subplot(2,3,3)
plt.title('GT')
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/DA/test_50/images/10_real_A.png')
plt.subplot(2,3,4)
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/DA/test_50/images/10_fake_B_visual.png')
plt.subplot(2,3,5)
imgplot = plt.imshow(img)
img = mpimg.imread('/content/result/DA/test_50/images/10_real_B_visual.png')
plt.subplot(2,3,6)
imgplot = plt.imshow(img)
plt.show()
